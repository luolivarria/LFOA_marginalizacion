# %% [markdown]
# Este documento es un archivo jupyter creado en un notebook de Google Colab.
#
# En el desarrollo del mismo se detalla cada uno de los incisos de la segunda parte del proyecto del módulo Programacion del Curso Propedeutico para ingreso a la Maestría en Ciencia de Datos 2023-2 de la Universidad de Sonora.
#
#
# 2 a.	Descargar y Leer el archivo de Base de Datos por Municipio 2020 del índice de marginación desde la página de descargas del gobierno federal mexicano en un dataframe. Los datos se encuentran en la pestaña "IMM 2020".

# %%
# Primero cargamos las librerias numpy, pandas y matplotlib para poder procesar la información.
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
excel_imm20_url = 'http://www.conapo.gob.mx/work/models/CONAPO/Marginacion/Datos_Abiertos/Municipio/IMM_2020.xls'
local_imm20_filename = "datos/IMM_2020.xls"

df_imm20 = pd.read_excel(excel_imm20_url, sheet_name=1, index_col=0)
df_imm20.head(5)
# Out:
#                 NOM_ENT  CVE_MUN         NOM_MUN  POB_TOT     ANALF  \
# CVE_ENT
# 1        Aguascalientes     1001  Aguascalientes   948990  1.644738
# 1        Aguascalientes     1002        Asientos    51536  3.526405
# 1        Aguascalientes     1003        Calvillo    58250  4.491509
# 1        Aguascalientes     1004           Cosío    17000  3.144867
# 1        Aguascalientes     1005     Jesús María   129929  2.380588
#
#              SBASC     OVSDE     OVSEE     OVSAE      OVPT       VHAC  \
# CVE_ENT
# 1        20.367220  0.104799  0.113169  0.378610  0.591434  10.339530
# 1        33.906364  2.650373  0.486448  0.858160  1.352430  22.942305
# 1        42.482450  0.365177  0.516760  0.800978  1.040411  19.219858
# 1        27.696745  0.712855  0.577354  0.659833  1.030989  22.716866
# 1        26.692477  0.277034  0.354957  0.860426  1.312652  16.404575
#
#            PL.5000      PO2SM    IM_2020   GM_2020  IMN_2020
# CVE_ENT
# ...

# %% [markdown]
# x

# %% [markdown]
# 2b.	Mostrar la descripción del DataFrame (medias, máximos mínimos, etc...) mostrar algunos hallazgos interesantes de la simple inspección visual y por estadísticas básicas de los datos.

# %%
df_imm20.describe(include='all')
# Out:
#        NOM_ENT       CVE_MUN        NOM_MUN       POB_TOT        ANALF  \
# count     2469   2469.000000           2469  2.469000e+03  2469.000000
# unique      32           NaN           2328           NaN          NaN
# top     Oaxaca           NaN  Benito Juárez           NaN          NaN
# freq       570           NaN              7           NaN          NaN
# mean       NaN  19324.164844            NaN  5.103849e+04    10.164466
# std        NaN   7382.892458            NaN  1.469907e+05     7.633633
# min        NaN   1001.000000            NaN  8.100000e+01     0.353446
# 25%        NaN  14079.000000            NaN  4.489000e+03     4.427755
# 50%        NaN  20226.000000            NaN  1.355200e+04     8.202762
# 75%        NaN  24027.000000            NaN  3.528400e+04    13.787294
# max        NaN  32058.000000            NaN  1.922523e+06    53.071253
#
#               SBASC        OVSDE        OVSEE        OVSAE         OVPT  \
# ...

# %% [markdown]
# 2c.	Realizar una gráfica que permita ver el porcentaje de municipios por estado con índices de marginación "muy bajo", "bajo", "medio", "alto" y "muy alto". Guarda la gráfica en archivo png

# %%
mar_por = df_imm20.groupby(["NOM_ENT", "GM_2020"])["POB_TOT"].sum().unstack()
mar_por.plot(kind='bar', figsize=(16,7))
pl.title("Población de municipios por Estado segun su Indice de Marginación")
pl.xlabel("Estados")
pl.ylabel("Población total")

#df_imm20.pivot(index='NOM_ENT', columns='GM_2020', values='IMN_2020').plot(kind='bar')


#ax = df_imm20.plot(figsize=(12,20), subplots=True)
#mar_por = df_imm20.IMN_2020.plot(rot=90, figsize=(32, 5))
#mar_munest= df_imm20(df_imm20.IMN_2020, columns=["Muy bajo", "Bajo", "Medio", "Alto", "Muy alto"])
#mar_por = df_imm20[['IM_2020']].groupby(df_imm20.index.NOM_ENT).plot(subplots=False, rot=90)

#Estuve trabajando en diferentes algoritmos para representar la poblacion en porcentaje pero no me funcionaron como esperaba.
# Out:
# Text(0, 0.5, 'Población total')

# %% [markdown]
# 2d.	Realizar una gráfica que muestre el porcentaje de la población, respecto a la población total de cada estado, con índices de marginación "muy bajo", "bajo", "medio", "alto" y "muy alto". Guarda la gráfica en formato jpg.

# %%
mar_pob = df_imm20.groupby(["NOM_ENT", "GM_2020"])["POB_TOT"].sum().unstack()
mar_pob.plot(kind='bar', figsize=(16,7))
pl.title("Población de municipios por Estado segun su Indice de Marginación")
pl.xlabel("Estados")
pl.ylabel("Población total")

#fig= mar_por.plot(kind='bar')
#fig.savefig("figura.jpg", dpi=200)
# Out:
# Text(0, 0.5, 'Población total')

# %% [markdown]
# 2e.	¿Hay coincidencias entra la gráficas anteriores?  ¿Algún hallazgo? Comenta tu análisis.

# %% [markdown]
# De acuerdo con el reporte de CONAPO si hay diferencias, ya que es diferente el análisis a nivel estado que a nivel municipio, en el nivel municipal permite distinguir en qué localidades se concentra la población conmayor indice de marginación y de esta manera focalizar las politicas publicas.

# %% [markdown]
# 2f.	Grafica la relación de porcentaje de analfabetismo respecto al porcentaje de poblaciones en localidades de menos de 5,000 habitantes.

# %%
p_analf= df_imm20.plot.scatter(
    x='PL.5000',
    y='ANALF',
    s=40,
    figsize=(16,7),
    title='Porcentaje de analfabetismo respecto al porcentaje de poblaciones en localidades de menos de 5,000 habitantes',
    xlabel='Porcentaje de poblacion que vive en localidades menores a 5,000 habitantes',
    ylabel='Porcentaje de poblacion analfabeta con edad mayor a 15 años',
)

# %% [markdown]
# 2g.	¿Existe una relación? ¿Cómo podrías analizar con que variable tiene mas correlación el porcentaje de analfabetismo en personas mayores de 15 años?

# %% [markdown]
# Se puede responder haciendo un grafico tipo scatter con el resto de las variables cuantitativas como SBASC, OVSDE, OVSEE, OVSAE, OVPT, VHAC, PL.5000 y PO2SM. Con una simple revision a los  plots creados comparados con la variable ANALF se puede ver la relacion entre este parámetro y los demás parámetros de carencias en educacion, servicios publicos y vivienda.

# %%
correlacion = df_imm20.plot(figsize=(12, 20), subplots=True)

# %% [markdown]
# 2h.	Desarrolla un nuevo DataFrame con indicadores interesantes por estado que se obtengan de los datos a nivel municipal y que pudieran ser de importancia a la hora de definir políticas públicas. Se va a calificar la originalidad de los indicadores. Justifica las decisiones que tomes, y guarda el nuevo dataframe en formato parquet.

# %%
df.to_parquet('myfile.parquet', engine='fastparquet')
